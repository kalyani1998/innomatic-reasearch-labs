# %% [markdown]
# #Descriptive Statistics
#      Descriptive statistics are brief informational coefficients that summarize a given data set,which can be either a representation of the entire population or a sample of a population.
# Descriptive statistics are broken down into measures of central tendency and measures of variability (spread).
# Measures of central tendency include the mean, median, and mode, while measures of variability include standard deviation, variance, minimum and maximum variables, kurtosis, and skewness.

# %%
#moudules:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm,skew
import statistics
import seaborn as sn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-d12fcfb21cc2> in <module>
#       4 from scipy.stats import norm,skew
#       5 import statistics
# ----> 6 import seaborn as sn
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#read csv file:
df = pd.read_csv('data.csv')
df

# %%
df.head(10)
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
# 5            14000              8000                  2                0
# 6            15000             16000                  3            35000
# 7            18000             20000                  5             8000
# 8            19000              9000                  2                0
# 9            20000              9000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# ...

# %%
df_1=df[['Mthly_HH_Income','Mthly_HH_Expense','Annual_HH_Income']]
df_1
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  Annual_HH_Income
# 0              5000              8000             64200
# 1              6000              7000             79920
# 2             10000              4500            112800
# 3             10000              2000             97200
# 4             12500             12000            147000
# 5             14000              8000            196560
# 6             15000             16000            167400
# 7             18000             20000            216000
# 8             19000              9000            218880
# 9             20000              9000            220800
# 10            20000             18000            278400
# 11            22000             25000            279840
# 12            23400              5000            292032
# 13            24000             10500            316800
# 14            24000             10000            244800
# 15            25000             12300            246000
# ...

# %% [markdown]
# #Measure of Central Tendency
# In statistics, a central tendency is a central or typical value for a probability distribution. Colloquially, measures of central tendency are often called averages. The term central tendency dates from the late 1920s.
# The most common measures of central tendency are ⬇
#
#   Mean
#   Median
#   Mode
#   Mean
# Defined as sum of all observations divided by total number of observations
# It can't be computed for categorical data.

# %%
df_1.mean()
# Out:
# Mthly_HH_Income      41558.00
# Mthly_HH_Expense     18818.00
# Annual_HH_Income    490019.04
# dtype: float64

# %% [markdown]
# #Median
# It is the middlemost observation when the data is arranged in ascending or descending order.
# The median divides the data into 2 equal parts- there will be an equal number of observations below and above the median.
# It is not based on all observations- thus it is not considered a very good representative.
#
# Formula
# mean.png

# %%
df_1.median()
# Out:
# Mthly_HH_Income      35000.0
# Mthly_HH_Expense     15500.0
# Annual_HH_Income    447420.0
# dtype: float64

# %% [markdown]
# #Mode
# It is the observation with the highest frequency
# Data can have more than one mode
# It can be calculated for continuous and categorical data

# %%
df.mode()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0            45000             25000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0            590400                 Graduate                      1

# %% [markdown]
# #Variance
# Variance is the expected value of the squared variation of a random variable from its mean value, in probability and statistics.
# Informally, variance estimates how far a set of numbers (random) are spread out from their mean value.
# The value of variance is equal to the square of standard deviation, which is another central tool.
# Variance is symbolically represented by σ2, s2, or Var(X).

# %%
df_1.var()
# Out:
# Mthly_HH_Income     6.811009e+08
# Mthly_HH_Expense    1.461733e+08
# Annual_HH_Income    1.024869e+11
# dtype: float64

# %% [markdown]
# #Standard Deviation
# The spread of statistical data is measured by the standard deviation. Distribution measures the deviation of data from its mean or average position. The degree of dispersion is computed by the method of estimating the deviation of data points. It is denoted by the symbol, ‘σ’.

# %%
df_1.std()
# Out:
# Mthly_HH_Income      26097.908979
# Mthly_HH_Expense     12090.216824
# Annual_HH_Income    320135.792123
# dtype: float64

# %% [markdown]
# #Correlation
# It provides direction and magnitude of linear relationship between variables It ranges from -1 to +1 where -1 indicates strong negative correlation and +1 indicates strong positive correlation.
# If corr(x,y)> 0 => Positive correlation.
# If corr(x,y)< 0 => Negative correlation.
# corr(x,y) = corr(y,x)
# corr(x,x) = corr(y,y) = 1
#
# The four types of correlation coefficients are given by:
# Pearson Correlation Coefficient
# Linear Correlation Coefficient
# Sample Correlation Coefficient
# Population Correlation Coefficient

# %%
np.corrcoef(df['Mthly_HH_Income'],df['Mthly_HH_Expense'])
# Out:
# array([[1.        , 0.64921525],
#        [0.64921525, 1.        ]])

# %%
r = np.array(df['Mthly_HH_Income'])
k = np.array(df['Mthly_HH_Expense'])
print (r)
print(k)
# Out:
# [  5000   6000  10000  10000  12500  14000  15000  18000  19000  20000
#   20000  22000  23400  24000  24000  25000  25000  25000  29000  30000
#   30500  32000  34000  34000  35000  35000  39000  40000  42000  43000
#   45000  45000  45000  45000  46000  47000  50000  50500  55000  60000
#   60000  65000  70000  80000  85000  90000  98000 100000 100000 100000]
# [ 8000  7000  4500  2000 12000  8000 16000 20000  9000  9000 18000 25000
#   5000 10500 10000 12300 20000 10000  6600 13000 25000 15000 19000 25000
#  12000 25000  8000 10000 15000 12000 25000 40000 10000 22000 25000 15000
#  20000 20000 45000 10000 50000 20000  9000 20000 25000 48000 25000 30000
#  50000 40000]

# %%
plt.title('Correlation')

plt.scatter(x,y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))
         (np.unique(x)), color='blue')

plt.xlabel(' Income')
plt.ylabel(' Expense')

plt.show()

# %% [markdown]
# #Normal Distribution
# The Normal Distribution is defined by the probability density function for a continuous random variable in a system.
# Let us say, f(x) is the probability density function and X is the random variable. Hence, it defines a function which is integrated between the range or interval (x to x + dx), giving the probability of random variable X, by considering the values between x and x+dx.

# %%
x_axis = np.array(df['Mthly_HH_Income'])
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
print(mean)
print(sd)
# Out:
# 41558
# 26097.908977540712

# %%
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %% [markdown]
# #Positively Skewed & Negatively Skewed Normal Distribution
# If one tail is longer than another, the distribution is skewed. These distributions are sometimes called asymmetric or asymmetrical distributions as they don’t show any kind of symmetry. Symmetry means that one half of the distribution is a mirror image of the other half. For example, the normal distribution is a symmetric distribution with no skew. The tails are exactly the same.
#
# A left-skewed distribution has a long left tail. Left-skewed distributions are also called negatively-skewed distributions. That’s because there is a long tail in the negative direction on the number line. The mean is also to the left of the peak.
#
# A right-skewed distribution has a long right tail. Right-skewed distributions are also called positive-skew distributions. That’s because there is a long tail in the positive direction on the number line. The mean is also to the right of the peak.

# %%
import scipy.stats as stats
data_points = np.array(df['Mthly_HH_Income'])
z = (data_points - np.mean(data_points))/np.std(data_points)

stats.probplot(z,dist='norm',plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
data_points = np.array(df['Mthly_HH_Income'])
fitted_data, fitted_lambda = stats.boxcox(data_points)
fig, ax = plt.subplots(1, 2)


sns.distplot(data_points, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2},
            label = "Non-Normal", color ="green", ax = ax[0])
 
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2},
            label = "Normal", color ="green", ax = ax[1])

plt.legend(loc = "upper right")
 
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-1d9d109ab9b0> in <module>
#       6 plt.plot(data_points, hist = False, kde = True,
#       7             kde_kws = {'shade': True, 'linewidth': 2},
# ----> 8             label = "Non-Normal", color ="green", ax = ax[0])
#       9
#      10 plt.plot(fitted_data, hist = False, kde = True,
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...
